# %%
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd
#matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
polygon = pd.read_csv("polygon.csv")
points = pd.read_csv("points.csv")

# %%
points
# Out:
#              x           y
# 0   563.585327    1.251259
# 1   808.740479  193.304245
# 2   479.873047  585.009338
# 3   895.962402  350.291443
# 4   746.604797  822.840027
# 5   858.943420  174.108093
# 6   513.534973  710.501404
# 7    14.984589  303.994873
# 8   364.452026   91.402939
# 9   165.898621  147.312851
# 10  445.692322  988.525024
# 11    4.669332  119.083221
# 12  377.880188    8.911405
# 13  571.184448  531.662964
# 14  607.165771  601.763977
# 15  663.045166  166.234314
# 16  352.122559  450.788910
# 17  607.684570   57.039093
# 18  802.606262  783.318604
# 19  301.950134  519.882813
# 20  726.676208  875.972778
# 21  925.717957  955.900757
# 22  142.338333  539.353638
# 23  235.328232  462.080750
# 24  209.601120  862.239441
# 25  843.653687  779.656372
# 26  999.694824  996.795532
# 27  392.437500  611.499390
# 28  297.280792  266.212952
# 29   23.743401  840.144043
# ..         ...         ...
# 70  374.980927  471.724609
# 71  316.873688  846.980164
# 72  271.889404  456.099121
# 73  297.799622  982.970642
# 74  567.278076  739.188843
# 75  761.314758  195.989868
# 76  397.656189  839.442139
# 77  890.163879  500.900299
# 78  994.628723   27.466658
# 79   50.508133  572.588257
# 80  194.067200  531.327271
# 81  626.758606  843.043335
# 82  197.851501  657.612854
# 83  123.325294  842.158264
# 84  743.125732  109.927673
# 85  941.068787  314.065979
# 86  336.313965  286.080505
# 87  733.085144  140.263077
# 88  707.998901  834.620178
# 89  747.215210  600.238037
# 90  144.474625  252.723770
# 91   61.006500    1.617481
# 92  852.626099  806.237976
# 93  115.604111  210.577713
# 94   14.252144  553.209045
# 95  454.512177  113.773003
# 96  686.147644  752.220215
# 97   73.885315  543.443115
# 98  201.940979  436.719879
# 99  290.353088  696.218750
#
# [100 rows x 2 columns]

# %%
x_pol = polygon["x"]
y_pol = polygon["y"]

x_p = points["x"]
y_p = points["y"]

# %%
plt.plot(x_pol, y_pol, color = 'blue', alpha = 0.7, linewidth = 1)
plt.title('Polygon')
plt.scatter(x_p, y_p, color = 'blue', s = 2)
plt.scatter(x_pol, y_pol, color = 'red', s = 3)
plt.savefig("res.png", dpi=600, pad_inches=0)
plt.show()
